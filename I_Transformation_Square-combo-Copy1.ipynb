# %% [markdown]
# ### I
# - transform - square
# - imp; bins mean
# - norm; z score

# %%
import Configure_Dataset 
df, y1, y2 = Configure_Dataset.configure('Competition1_raw_data.xlsx')
df.head(10)
# Out:
#       C1   C2        C4       C7  %_long_sentences  %_long_words  \
# 0  122.0  1.0  0.029074   51.345          0.640426      0.054250
# 1  259.0  0.0 -0.013352   25.936          0.644753      0.051395
# 2   90.0  1.0  0.020715    7.378          0.636816      0.061764
# 3  209.0  1.0  0.020023    8.526          0.539634      0.061630
# 4   80.0  1.0 -0.034895  632.298          0.587413      0.048550
# 5   94.0  1.0 -0.057556  197.591          0.643137      0.045280
# 6  128.0  1.0  0.004106    5.146          0.765657      0.044295
# 7   91.0  0.0  0.040620      NaN          0.826347           NaN
# 8  100.0  1.0 -0.029316  279.600          0.540323      0.061905
# 9  106.0  1.0 -0.024925  494.008          0.514286      0.050252
#
#    %_positive_words  %_negative_words  %_uncertain_words  C3'        C5'  \
# 0          0.004875          0.009199           0.010929    1   3.864345
# 1          0.003258          0.011105           0.010876    0  12.028832
# ...

# %%
df1 = df[["C1","C2","C4","C7","C3'","C5'","C6'"]]
df2 = df[["%_long_sentences", "%_long_words","%_positive_words", "%_negative_words", "%_uncertain_words","one_hot_Manufacturing", "one_hot_Other", "one_hot_Public Services"]]

# %%
from Transform import skew_transform_square
df2 = skew_transform_square(df2)
# Out:
# /home/jupyter-mbrowne/2019-competition1-3-musketeers/Transform.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data[key] = np.square(data[key])
# /home/jupyter-mbrowne/2019-competition1-3-musketeers/Transform.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data[key] = np.sqrt(data[key])

# %%
import Impute
df2 = Impute.impute_mean(df2)

# %%
import ImputeUsingBins
df1 = ImputeUsingBins.impute_bin_mean(df1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-548e6797ae4f> in <module>()
#       1 import ImputeUsingBins
# ----> 2 df1 = ImputeUsingBins.impute_bin_mean(df1)
#
# ~/2019-competition1-3-musketeers/ImputeUsingBins.py in impute_bin_mean(df)
#       6
#       7
# ----> 8     data = df.fillna(df.groupby(["one_hot_Manufacturing","one_hot_Other","one_hot_Public Services"]).transform('mean'))
#       9
#      10
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6663         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6664                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6665                        observed=observed, **kwargs)
#    6666
# ...

# %%
from Transform import skew_transform_square
df1 = skew_transform_square(df1)
# Out:
# /home/jupyter-mbrowne/2019-competition1-3-musketeers/Transform.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data[key] = np.sqrt(data[key])
# /home/jupyter-mbrowne/2019-competition1-3-musketeers/Transform.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data[key] = np.square(data[key])

# %%
import pandas as pd

# %%
df = pd.concat([df1, df2], axis=1) # df = pd.join([df1, df2])

# %%
df.isnull().sum()
# Out:
# C1                          0
# C2                          0
# C4                          0
# C7                         60
# C3'                         0
# C5'                         0
# C6'                         0
# %_long_sentences            0
# %_long_words                0
# %_positive_words            0
# %_negative_words            0
# %_uncertain_words           0
# one_hot_Manufacturing       0
# one_hot_Other               0
# one_hot_Public Services     0
# dtype: int64

# %%
df.head(10)
# Out:
#           C1   C2        C4         C7  C3'       C5'       C6'  \
# 0  11.045361  1.0  0.029074   7.165543    1  1.965794  3.333333
# 1  16.093477  0.0 -0.013352   5.092740    0  3.468261  0.000000
# 2   9.486833  1.0  0.020715   2.716247    0  1.835520  0.000000
# 3  14.456832  1.0  0.020023   2.919932    0  1.816507  0.000000
# 4   8.944272  1.0 -0.034895  25.145536    1  1.930355  2.236068
# 5   9.695360  1.0 -0.057556  14.056707    1  2.392571  0.000000
# 6  11.313708  1.0  0.004106   2.268480    0  1.860939  0.000000
# 7   9.539392  0.0  0.040620        NaN    0  1.556107  0.000000
# 8  10.000000  1.0 -0.029316  16.721244    0  2.194673  0.000000
# 9  10.295630  1.0 -0.024925  22.226291    1  1.748316  0.000000
#
#    %_long_sentences  %_long_words  %_positive_words  %_negative_words  \
# 0          0.410145      0.054250          0.069818          0.095911
# 1          0.415707      0.051395          0.057080          0.105380
# ...

# %%
from Normalize import z_score
df=z_score(df)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-cb18da5183d9> in <module>()
#       1 from Normalize import z_score
# ----> 2 df=z_score(df)
#       3 df.head()
#
# ~/2019-competition1-3-musketeers/Normalize.py in z_score(df)
#      24     scaler = preprocessing.StandardScaler()
#      25
# ---> 26     data_scaled = scaler.fit_transform(data)
#      27
#      28     df = pd.DataFrame(data_scaled)
#
# /opt/tljh/user/lib/python3.6/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     515         if y is None:
#     516             # fit method of arity 1 (unsupervised transformation)
# --> 517             return self.fit(X, **fit_params).transform(X)
#     518         else:
#     519             # fit method of arity 2 (supervised transformation)
#
# ...

# %%
import Combine
I = Combine.combine(df, y1, y2)
I.head()
# Out:
#           C1   C2        C4         C7  C3'       C5'       C6'  \
# 0  11.045361  1.0  0.029074   7.165543    1  1.965794  3.333333
# 1  16.093477  0.0 -0.013352   5.092740    0  3.468261  0.000000
# 2   9.486833  1.0  0.020715   2.716247    0  1.835520  0.000000
# 3  14.456832  1.0  0.020023   2.919932    0  1.816507  0.000000
# 4   8.944272  1.0 -0.034895  25.145536    1  1.930355  2.236068
#
#    %_long_sentences  %_long_words  %_positive_words  %_negative_words  \
# 0          0.410145      0.054250          0.069818          0.095911
# 1          0.415707      0.051395          0.057080          0.105380
# 2          0.405535      0.061764          0.107669          0.079192
# 3          0.291205      0.061630          0.098420          0.084521
# 4          0.345054      0.048550          0.067215          0.100236
#
#    %_uncertain_words  one_hot_Manufacturing  one_hot_Other  \
# 0           0.104540                      1            0.0
# ...

# %%
import pandas as pd
I.to_csv('./Datasets/I_combo2.csv')
