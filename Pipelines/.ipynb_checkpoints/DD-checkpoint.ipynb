# %% [markdown]
# # Stuart's DD Dataset
# #### Attempted to Normalized using z-score for null values first but received this error:
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
# #### Imputed mean for null values

# %%
import Configure_Dataset 
DD, y1, y2 = Configure_Dataset.configure('Competition1_raw_data.xlsx')
DD.head()
# Out:
#       C1   C2        C4       C7  %_long_sentences  %_long_words  \
# 0  122.0  1.0  0.029074   51.345          0.640426      0.054250
# 1  259.0  0.0 -0.013352   25.936          0.644753      0.051395
# 2   90.0  1.0  0.020715    7.378          0.636816      0.061764
# 3  209.0  1.0  0.020023    8.526          0.539634      0.061630
# 4   80.0  1.0 -0.034895  632.298          0.587413      0.048550
#
#    %_positive_words  %_negative_words  %_uncertain_words  C3'        C5'  \
# 0          0.004875          0.009199           0.010929    1   3.864345
# 1          0.003258          0.011105           0.010876    0  12.028832
# 2          0.011593          0.006271           0.011403    0   3.369134
# 3          0.009686          0.007144           0.013319    0   3.299697
# 4          0.004518          0.010047           0.011261    1   3.726269
#
#          C6'  one_hot_Manufacturing  one_hot_Other  one_hot_Public Services
# ...

# %%
DD.isnull().sum()
# Out:
# C1                          0
# C2                          0
# C4                          0
# C7                         60
# %_long_sentences            0
# %_long_words                3
# %_positive_words            3
# %_negative_words            2
# %_uncertain_words           2
# C3'                         0
# C5'                         0
# C6'                         0
# one_hot_Manufacturing       0
# one_hot_Other               0
# one_hot_Public Services     0
# dtype: int64

# %%
#importnumpy ndarray for use in sklearn
import Normalize

# %%
#use z score to normalize the data
DD = Normalize.z_score(DD)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-b64ee4ebc549> in <module>()
#       1 #use z score to normalize the data
# ----> 2 DD = Normalize.z_score(DD)
#
# ~/BA545-data/2019-competition1-3-musketeers/Normalize.py in z_score(df)
#      24     scaler = preprocessing.StandardScaler()
#      25
# ---> 26     data_scaled = scaler.fit_transform(data)
#      27
#      28     df = pd.DataFrame(data_scaled)
#
# /opt/tljh/user/lib/python3.6/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     515         if y is None:
#     516             # fit method of arity 1 (unsupervised transformation)
# --> 517             return self.fit(X, **fit_params).transform(X)
#     518         else:
#     519             # fit method of arity 2 (supervised transformation)
#
# ...

# %%
DD.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.181588  0.404995  0.654566 -0.287913  0.176554  0.310453 -0.251345
# 1  0.715586 -2.469165 -0.619777 -0.303969  0.232307 -0.110317 -1.181627
# 2 -0.391147  0.404995  0.403480 -0.315697  0.130054  1.418052  3.614727
# 3  0.388150  0.404995  0.382698 -0.314971 -1.121856  1.398322  2.517770
# 4 -0.456634  0.404995 -1.266863  0.079213 -0.506367 -0.529648 -0.456636
#
#          7         8         9         10        11        12        13  \
# 0  0.057427 -0.201253  1.046536 -0.107787  0.525006  1.003035 -0.347193
# 1  0.703523 -0.220083 -0.955533  1.483840 -0.497238  1.003035 -0.347193
# 2 -0.934841 -0.032806 -0.955533 -0.204326 -0.497238  1.003035 -0.347193
# 3 -0.639159  0.648229 -0.955533 -0.217863 -0.497238  1.003035 -0.347193
# 4  0.344982 -0.083112  1.046536 -0.134705 -0.037228 -0.996974 -0.347193
#
#          14
# 0 -0.806226
# 1 -0.806226
# 2 -0.806226
# 3 -0.806226
# 4  1.240347

# %%
import Impute
DD = Impute.impute_mean(DD)

# %%
DD.isnull().sum()
# Out:
# C1                         0
# C2                         0
# C4                         0
# C7                         0
# %_long_sentences           0
# %_long_words               0
# %_positive_words           0
# %_negative_words           0
# %_uncertain_words          0
# C3'                        0
# C5'                        0
# C6'                        0
# one_hot_Manufacturing      0
# one_hot_Other              0
# one_hot_Public Services    0
# dtype: int64

# %%
import Combine
DDdata = Combine.combine(DD, y1, y2)
DDdata.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.181588  0.404995  0.654566 -0.287913  0.176554  0.310453 -0.251345
# 1  0.715586 -2.469165 -0.619777 -0.303969  0.232307 -0.110317 -1.181627
# 2 -0.391147  0.404995  0.403480 -0.315697  0.130054  1.418052  3.614727
# 3  0.388150  0.404995  0.382698 -0.314971 -1.121856  1.398322  2.517770
# 4 -0.456634  0.404995 -1.266863  0.079213 -0.506367 -0.529648 -0.456636
#
#           7         8         9        10        11        12        13  \
# 0  0.057427 -0.201253  1.046536 -0.107787  0.525006  1.003035 -0.347193
# 1  0.703523 -0.220083 -0.955533  1.483840 -0.497238  1.003035 -0.347193
# 2 -0.934841 -0.032806 -0.955533 -0.204326 -0.497238  1.003035 -0.347193
# 3 -0.639159  0.648229 -0.955533 -0.217863 -0.497238  1.003035 -0.347193
# 4  0.344982 -0.083112  1.046536 -0.134705 -0.037228 -0.996974 -0.347193
#
#          14  Y1  Y2
# 0 -0.806226   0   1
# 1 -0.806226   1   0
# 2 -0.806226   1   0
# ...
