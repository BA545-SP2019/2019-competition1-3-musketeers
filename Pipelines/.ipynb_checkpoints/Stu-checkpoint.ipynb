# %% [markdown]
# # Competition 1
#
# ## the purpose of this notebook is for independent work prior to a group merge
#
# backround info on the topic
#
# directions as to what we did (to be filled out later)
#
# here are our steps

# %%
# importing proper libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import sklearn

# %% [markdown]
# Here is the data dictionary in used as a reference of column names.
# ![Variable Dictionary](data_dictionary.PNG)

# %%
# create an initial data frame from data provided
df  = pd.read_excel('Competition1_raw_data.xlsx', header=0,)
df.head()
# Out:
#      I1                                  I2    I3 P(IPO) P(H) P(L) P(1Day)  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674     10  9.5  8.5   11.87
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834      8   10    8    7.25
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834      7   14   12     6.7
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834   11.5   16   14   12.39
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492     21   21   19    56.6
#
#     C1 C2    C3 ...         C6       C7   T1     T2     T3   T4    T5  S1  \
# 0  122  1  3.43 ...   10600000   51.345  470  12719  11560  301   690  62
# 1  259  0 -1.62 ...    2400000   25.936  791  21792  19585  510  1120  71
# 2   90  1 -1.24 ...    5000000    7.378  201   5262   4785  128   325  61
# 3  209  1 -0.91 ...    4500000    8.526  328   8259   7574  177   509  80
# 4   80  1  0.07 ...    8250000  632.298  572  14830  13176  336   720  67
#
#     S2   S3
# 0  117  139
# 1  242  237
# 2   33   60
# 3   59  110
# ...

# %% [markdown]
# ## We will perform an prelimanry EDA to understand the characteristics of the data
#
# ## First, we will view the data types, count, and simple distributions

# %% [markdown]
# # look at column values and their types
# df.info()

# %% [markdown]
# Every column is classified as an object; but we know that some columns, like C1 should be at least an integer. We will view several columns to see if they share a common source error

# %%
df['C1'].value_counts()
# Out:
# -      22
# 93     15
# 84     14
# 77     13
# 92     13
# 112    12
# 91     12
# 119    12
# 85     11
# 78     10
# 100    10
# 76     10
# 104    10
# 111    10
# 94     10
# 98      9
# 105     9
# 79      8
# 147     7
# 140     7
# 89      7
# 124     7
# 83      7
# 70      7
# 72      7
# 106     7
# 107     7
# 90      7
# 118     6
# 133     6
#        ..
# 161     1
# 506     1
# 153     1
# 658     1
# 131     1
# 203     1
# 206     1
# 257     1
# 25      1
# 251     1
# 243     1
# 307     1
# 241     1
# 240     1
# 237     1
# 234     1
# 233     1
# 230     1
# 227     1
# 207     1
# 226     1
# 225     1
# 736     1
# 223     1
# 222     1
# 218     1
# 217     1
# 215     1
# 213     1
# 520     1
# Name: C1, Length: 245, dtype: int64

# %% [markdown]
# There are 22 instances of "-", which the data dictionary defines as a missing value. This format is not useful for analysis, so we will convert all '-' to NaN values.

# %%
df = df.replace('-', np.NaN)

# %%
df.head(15)
# Out:
#       I1                                     I2    I3  P(IPO)  P(H)  P(L)  \
# 0   AATI     ADVANCED ANALOGIC TECHNOLOGIES INC  3674    10.0   9.5   8.5
# 1   ABPI        ACCENTIA BIOPHARMACEUTICALS INC  2834     8.0  10.0   8.0
# 2   ACAD             ACADIA PHARMACEUTICALS INC  2834     7.0  14.0  12.0
# 3   ACHN          ACHILLION PHARMACEUTICALS INC  2834    11.5  16.0  14.0
# 4   ACLI        AMERICAN COMMERCIAL LINES INC.   4492    21.0  21.0  19.0
# 5   ACOM                     Ancestry.com Inc.   7379    13.5  14.5  12.5
# 6   ACOR                ACORDA THERAPEUTICS INC  2836     6.0  13.0  11.0
# 7   ACRX             ACELRX PHARMACEUTICALS INC  2834     5.0  14.0  12.0
# 8   ACTV                     ACTIVE NETWORK INC  7372    15.0  18.0  16.0
# 9    ACW                          ACCURIDE CORP  3714     9.0  19.0  17.0
# 10  ADKU             ADCARE HEALTH SYSTEMS, INC   NaN     NaN   NaN   NaN
# 11  ADLS  Advanced Life Sciences Holdings, Inc.  2854     5.0   9.0   8.0
# ...
