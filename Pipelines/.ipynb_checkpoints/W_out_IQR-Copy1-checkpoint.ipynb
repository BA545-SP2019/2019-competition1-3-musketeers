# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import Configure_Dataset 
df, y1, y2 = Configure_Dataset.configure('Competition1_raw_data.xlsx')
df.head(10)
# Out:
#       C1   C2        C4       C7  %_long_sentences  %_long_words  \
# 0  122.0  1.0  0.029074   51.345          0.640426      0.054250
# 1  259.0  0.0 -0.013352   25.936          0.644753      0.051395
# 2   90.0  1.0  0.020715    7.378          0.636816      0.061764
# 3  209.0  1.0  0.020023    8.526          0.539634      0.061630
# 4   80.0  1.0 -0.034895  632.298          0.587413      0.048550
# 5   94.0  1.0 -0.057556  197.591          0.643137      0.045280
# 6  128.0  1.0  0.004106    5.146          0.765657      0.044295
# 7   91.0  0.0  0.040620      NaN          0.826347           NaN
# 8  100.0  1.0 -0.029316  279.600          0.540323      0.061905
# 9  106.0  1.0 -0.024925  494.008          0.514286      0.050252
#
#    %_positive_words  %_negative_words  %_uncertain_words  C3'        C5'  \
# 0          0.004875          0.009199           0.010929    1   3.864345
# 1          0.003258          0.011105           0.010876    0  12.028832
# ...

# %%
df.describe()
# Out:
#                 C1          C2          C4            C7  %_long_sentences  \
# count   660.000000  660.000000  660.000000    600.000000        660.000000
# mean    149.728788    0.859091    0.007282    506.948305          0.626720
# std     152.817467    0.348192    0.033318   1661.058320          0.077686
# min      10.000000    0.000000   -0.162352      0.074000          0.000000
# 25%      85.000000    1.000000   -0.013927     37.883000          0.580329
# 50%     107.000000    1.000000    0.009125    107.462000          0.628861
# 75%     155.250000    1.000000    0.031571    332.505500          0.674461
# max    2087.000000    1.000000    0.092896  30683.000000          0.826347
#
#        %_long_words  %_positive_words  %_negative_words  %_uncertain_words  \
# count    657.000000        657.000000        658.000000         658.000000
# mean       0.052143          0.005311          0.009029           0.011495
# ...

# %%
pd.DataFrame.hist(df, figsize = [15,15]);

# %%
#Outlier Treatment

def outlier_detect(df):
    for i in df.describe().columns:
        Q1=df.describe().at['25%',i]
        Q3=df.describe().at['75%',i]
        IQR=Q3 - Q1
        LTV=Q1 - 1.5 * IQR
        UTV=Q3 + 1.5 * IQR
        x=np.array(df[i])
        p=[]
        for j in x:
            if j < LTV:
                p.append(LTV)
            elif j > UTV:
                p.append(UTV)
            else:
                p.append(j)
        df[i]=p
    return df
outlier_detect(df[["C1","C4","C7","%_long_sentences","%_long_words","%_positive_words","%_negative_words","%_uncertain_words","C5'","C6'"]])
# Out:
# /opt/tljh/user/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#           C1        C4          C7  %_long_sentences  %_long_words  \
# 0    122.000  0.029074   51.345000          0.640426      0.054250
# 1    259.000 -0.013352   25.936000          0.644753      0.051395
# 2     90.000  0.020715    7.378000          0.636816      0.061764
# 3    209.000  0.020023    8.526000          0.539634      0.061630
# 4     80.000 -0.034895  632.298000          0.587413      0.048550
# 5     94.000 -0.057556  197.591000          0.643137      0.045280
# 6    128.000  0.004106    5.146000          0.765657      0.044295
# 7     91.000  0.040620  197.867537          0.815658      0.053139
# ...

# %%
df.describe()
# Out:
#                C1     C2          C4          C7  %_long_sentences  \
# count  660.000000  660.0  660.000000  600.000000        660.000000
# mean   126.911932    1.0    0.007433  233.215028          0.628160
# std     64.094744    0.0    0.032757  265.219227          0.069922
# min     10.000000    1.0   -0.082174    0.074000          0.439132
# 25%     85.000000    1.0   -0.013927   37.883000          0.580329
# 50%    107.000000    1.0    0.009125  107.462000          0.628861
# 75%    155.250000    1.0    0.031571  332.505500          0.674461
# max    260.625000    1.0    0.092896  774.439250          0.815658
#
#        %_long_words  %_positive_words  %_negative_words  %_uncertain_words  \
# count    657.000000        657.000000        658.000000         658.000000
# mean       0.052135          0.005281          0.008955           0.011406
# std        0.006728          0.001650          0.002723           0.002503
# ...

# %%
#def replace(group):
   # mean, std = group.mean(), group.std()
   # outliers = (group - mean).abs() > 3*std
   # group[outliers] = mean        # or "group[~outliers].mean()"
    #return group

#df.groupby('a').transform(replace)

# %%
def normalize(column):
    upper = column.max()
    lower = column.min()
    y = (column - lower)/(upper-lower)
    return y
normalize(df)
df.describe()
# Out:
#                C1     C2          C4          C7  %_long_sentences  \
# count  660.000000  660.0  660.000000  600.000000        660.000000
# mean   126.911932    1.0    0.007433  233.215028          0.628160
# std     64.094744    0.0    0.032757  265.219227          0.069922
# min     10.000000    1.0   -0.082174    0.074000          0.439132
# 25%     85.000000    1.0   -0.013927   37.883000          0.580329
# 50%    107.000000    1.0    0.009125  107.462000          0.628861
# 75%    155.250000    1.0    0.031571  332.505500          0.674461
# max    260.625000    1.0    0.092896  774.439250          0.815658
#
#        %_long_words  %_positive_words  %_negative_words  %_uncertain_words  \
# count    657.000000        657.000000        658.000000         658.000000
# mean       0.052135          0.005281          0.008955           0.011406
# std        0.006728          0.001650          0.002723           0.002503
# ...

# %%
def sigmoid(x):
    e = np.exp(1)
    y = 1/(1+e**(-x))
    return y
sigmoid(df)
df.describe()
# Out:
#                C1     C2          C4          C7  %_long_sentences  \
# count  660.000000  660.0  660.000000  600.000000        660.000000
# mean   126.911932    1.0    0.007433  233.215028          0.628160
# std     64.094744    0.0    0.032757  265.219227          0.069922
# min     10.000000    1.0   -0.082174    0.074000          0.439132
# 25%     85.000000    1.0   -0.013927   37.883000          0.580329
# 50%    107.000000    1.0    0.009125  107.462000          0.628861
# 75%    155.250000    1.0    0.031571  332.505500          0.674461
# max    260.625000    1.0    0.092896  774.439250          0.815658
#
#        %_long_words  %_positive_words  %_negative_words  %_uncertain_words  \
# count    657.000000        657.000000        658.000000         658.000000
# mean       0.052135          0.005281          0.008955           0.011406
# std        0.006728          0.001650          0.002723           0.002503
# ...

# %%
pd.DataFrame.hist(df, figsize = [15,15]);

# %%
#find out missing values
names = []
value = []
for col in df.columns:
    names.append(col)
    value.append(df[col].isnull().sum())
    print("number of missing values: ", names[-1], value[-1], """                  """, "Percentage of missing values:", names[-1], round((value[-1]/682)*100))
# Out:
# number of missing values:  C1 0                    Percentage of missing values: C1 0.0
# number of missing values:  C2 0                    Percentage of missing values: C2 0.0
# number of missing values:  C4 0                    Percentage of missing values: C4 0.0
# number of missing values:  C7 60                    Percentage of missing values: C7 9.0
# number of missing values:  %_long_sentences 0                    Percentage of missing values: %_long_sentences 0.0
# number of missing values:  %_long_words 3                    Percentage of missing values: %_long_words 0.0
# number of missing values:  %_positive_words 3                    Percentage of missing values: %_positive_words 0.0
# number of missing values:  %_negative_words 2                    Percentage of missing values: %_negative_words 0.0
# number of missing values:  %_uncertain_words 2                    Percentage of missing values: %_uncertain_words 0.0
# ...

# %%
import ImputeUsingBins
df = ImputeUsingBins.impute_bin_mean(df)

# %%
#find out missing values
names = []
value = []
for col in df.columns:
    names.append(col)
    value.append(df[col].isnull().sum())
    print("number of missing values: ", names[-1], value[-1], """                  """, "Percentage of missing values:", names[-1], round((value[-1]/682)*100))
# Out:
# number of missing values:  C1 0                    Percentage of missing values: C1 0.0
# number of missing values:  C2 0                    Percentage of missing values: C2 0.0
# number of missing values:  C4 0                    Percentage of missing values: C4 0.0
# number of missing values:  C7 0                    Percentage of missing values: C7 0.0
# number of missing values:  %_long_sentences 0                    Percentage of missing values: %_long_sentences 0.0
# number of missing values:  %_long_words 0                    Percentage of missing values: %_long_words 0.0
# number of missing values:  %_positive_words 0                    Percentage of missing values: %_positive_words 0.0
# number of missing values:  %_negative_words 0                    Percentage of missing values: %_negative_words 0.0
# number of missing values:  %_uncertain_words 0                    Percentage of missing values: %_uncertain_words 0.0
# ...

# %%
import Combine
df = Combine.combine(df, y1, y2)
df.head()
# Out:
#       C1   C2        C4       C7  %_long_sentences  %_long_words  \
# 0  122.0  1.0  0.029074   51.345          0.640426      0.054250
# 1  259.0  1.0 -0.013352   25.936          0.644753      0.051395
# 2   90.0  1.0  0.020715    7.378          0.636816      0.061764
# 3  209.0  1.0  0.020023    8.526          0.539634      0.061630
# 4   80.0  1.0 -0.034895  632.298          0.587413      0.048550
#
#    %_positive_words  %_negative_words  %_uncertain_words  C3'       C5'  \
# 0          0.004875          0.009199           0.010929    1  3.864345
# 1          0.003258          0.011105           0.010876    0  7.868826
# 2          0.009434          0.006271           0.011403    0  3.369134
# 3          0.009434          0.007144           0.013319    0  3.299697
# 4          0.004518          0.010047           0.011261    1  3.726269
#
#          C6'  one_hot_Manufacturing  one_hot_Other  one_hot_Public Services  \
# ...

# %%
df.to_csv('./Datasets/w_out_IQR.csv')
